# %% [markdown]
# # errors
#
# - 0 is an even number!
#
# - if f of Lf belongs to P -> f belongs to FP. BUT if f belongs to FP DOES NOT NECESSARLY IMPLY THAT Lf belongs to P!!
#
# - (?) If a function belongs to FEXP then the associate language belongs to EXP. (the vice versa doesn't necessarly holds).
#
# - the EXP class is defined by the bound $2^{n^c}$
#
# -  The definition of a prime number is a positive integer that has exactly two positive divisors. Note that 1 is not a prime number, 2 is a prime number.
#
# - given A={1,2} B={3} the disjoint sum is {(1,),(2,),(,3)}, the disjoint union is {(1,0),(2,0),(3,1)}.
#
# - composite number = not prime.
#
# - X ∨¬X is 2CNF or 1CNF? 2CNF!!!
#
# - how do you prove that a problem is hard? prove it is in NP-complete.
#
# - How are related two NP-complete problems H,L in terms of ≤p? they are equivalent: L ≤p H and H ≤p L. Does this mean that to find a reduction from H to L it's easy as finding it from L to H? not at all, one can be much more difficult to be found than the other, ALSO IF YOU'RE ENSURED THAT IT EXISTS. (Example: from 3SAT to SAT is the identity, to do the vice versa you must reason on it.)
#
# - What is the reduction from 3SAT to SAT? the identity! a 3CNF is already a CNF.
#
# - Is it MIS NP-complete? NO! it is not a language so it can't be. the correspondent language "INDSET" is NP-complete.
#
# - Why do we want to encode everything in BINARY STRINGS?? because it is a DISCRETE SET, the cardinality is countable, and they're also closer to how data is stored in the hardware.
#
# - as this course taught to you remember: before solving a problem ask yourself "can be solved"? how much difficult is to answer this question? to answer this question is the same as solving a millenium problem?
#
# - the input of a TM must be encoded as a single binary string, not a set of strings!
#
# - how can you encode a pair into a binary string?  encode 1 as 11, 0 as 00, and the separation between the two elements of the pair with 01 (or 10).
#
# - a directed graph is G(E,V) where E is encoded as a SET OF PAIRS!. Instead an undirected graph encodes E as a SET OF SETS.
#
# - G0 = (V0,E0) is a subgraph of G=(V,E) iff V0 subset of V and E0 = (E intersection (V0xV0)).
#
# - G1 is an isomorphism of G2 iff there's a function (called omorphism) h:V1->V2 which preserves the edge relation:  u,v in E1 ->  h(u),h(v) in E2.
#
# - A NDTM, IS SAID TO "ACCEPT" if AT LEAST ONE branch ends up in qaccept.
#
# - A NDTM runs in time T if EVERY BRANCH stops in qaccept or qhalt in AT MOST cT steps.
#
# - in binary the product by 2 can be done simply shifting the string on the left (for the division on the right).
#
# - tasks are divided into languages and functions. The specific way they're solved are called "processes" or "algorithms".

# %% [markdown]
# # Problems in P:
#
# - Numbers: PRIMALITY/COMPOSITE test (AKS algorithm), exponentiation, addition O(n), multiplication O(n^2),
#
# - Strings: matching, approximate matching, parity, comparison, palindrome, 2SAT.
#
# - Lists: inversion, sorting, find maximum/minimum.
#
# - Graphs: reachability, shortest paths, minimum spanning trees.
#
# - Optimization: Decisional LP is in P thanks to the ELLIPSOID algorithm, NOT THE SIMPLEX ALGORITHM WHICH HAS EXPONENTIAL TIME IN THE WORST CASE. But why is the simplex algorithms so famous? because the average running time is lower than all the other algorithms of linear programming. Note: LP constists simply in knowing what is the assignments which satisfies all the linear inequalities. certificate: the assignment to the variables.
#
#
# # Problems in NP:
#
# - factoring is in NP. It is this problem: Given three numbers n,m,l, it asks whether n has a PRIME FACTOR p in the interval [m,l]. Certificate:  it can be taken to be the prime number p: checking that p ∈ [m,l] and that p divides n is easy. Instead, checking that p is prime requires a lot of work, but can be done in polynomial time!
#
# - SAT and 3SAT are NP complete (cook-levin theorem).
#
# - Decisional 0/1 Linear Programming is in NP-complete!!! note how even if the domain is restricted the problem is NP because it hasn't been found an efficient solution yet. It is NP-complete. There's an easy polytime reduction from SAT to ILP.
#
# - MIS, it is in FEXP. The relative decision problem "INDSET" is in EXP and it is also NP-complete.
#
# - Subset SUM is in NP-complete. (reduction from OL3SAT; certificate = subset of indexes).
#     - Subset SUM problem: given a set of integers, there's a subset which sum is equal to N?.
#
# - CLIQUE is NP-complete.
#
# - Set Packing is NP-complete.
#
# - Node-cover is NP-complete.
#
# # general tips:
#
# - When you have a problem with RELATIONS, pairs etc probably you must encode it as a GRAPH!!

# %% [markdown]
# # MUST REMEMBER:
#
# # function COMPUTABLE:
# f {0,1}∗ →{0,1}∗ is computable iff exists a TM M for which M(x) = f(x) for every x ∈{0,1}∗.
#
# # function COMPUTABLE in time T:N->N :
#
# f {0,1}∗ →{0,1}∗ is computable in time T:N->N iff exists a TM M for which M(x) returns f(x) in a number of steps smaller or equal to T(|x|) for every x ∈{0,1}∗.
#
# # Language DECIDABLE (in time T):
# A language Lf ⊆{0,1}∗ is decidable (in time T) iﬀ f is computable (in time T).
#
# # time-constructible
# A function T : N→N is time-constructible iﬀ the function on {0,1}∗ deﬁned as x → <T(|x|)> is computable.
#
# (which means that a function (usually those we use as time bounds), is said to be time-constructable iff the function transformed in one which takes as input the encoding of its input in a binary string, and as output the encoding of its output in a binary string, is computable.)
#
# (Examples for time-constructible functions are n, nlogn, n^2, 2n. Almost all functions encountered in this book will be time-constructible and, to avoid annoying anomalities, we will restrict our attention to time bounds of this form).
#
# Example of non time constructible function: https://math.stackexchange.com/questions/55096/non-time-constructible-functions.
#
# # simple vs complex TM:
# Theorem: The more restrictive notion of machine simulates the most general one with polynomial overhead.
#
# This is a theorem which we didn't proved.
#
# Do not confuse it with the Church-Turing thesis which relates TMs with any physically realizable computer, and it is not proved.
#
# ( that's why we don't care: the definition of feasibility and the classification of tasks on computational complexity is invariant to polynomial overheads, in other words classes P and NP are CLOSED y polynomial overheads).
#
# There's an even more important thing: TM has only a polynomial overhead also on other models such as RAM, lambda-calculus..
#
# Even more: according to the  Strong Church-Turing thesis, it is thought that the simplest TM can simulate with polynomial overhead any possible realizable computing machine.
#
# More in detail:
#
# Turing machines are not as efficient as RAM machines. A RAM machine can access an arbitrary tape location in O(1). A Turing machine can't. A RAM machine can do arithmetic in O(1) (under certain restrictions). A Turing machine can't.
#
# Turing machines polynomially simulate RAM machines, that is, for some constant c, any RAM machine running in time O(n^k) can be simulated by a Turing machine running in time O(n^{ck}). (The constant is pretty reasonable, about 2, depending on the Turing machine model.)
#
# # complexity class
# A complexity class is a set of tasks which can be computed within some prescribed resource bounds. The classes we've seen are based on the worst case, but there are classes based on the best and on the average case).
#
# # DTIME(T(n)):
# The DTIME(T(n)) is the set of languages decidable (by a deterministic TM) in time c*T(n) for some constant c.
#
# Why is this classification not robust?
# It is dependent on the computational model chosen, classes too small.
#
# # Class P:
# The set of languages decidable by a deterministic TM in polynomial time. Can be defined also as class P = U c>=1 DTIME(n^c).
#
# # (Strong) Church-Turing Thesis:
#
# - Thesis: Any physically realizable computer can be simulated by a TM with a (polynomial) overhead in time. This justify the use of TM.
#
# - Consequence: The class (P) of computable tasks wouldn't be larger (would be the same) if defined based on other realistic models of computation. This justifies the robustness of the class P.
#
# - Not something proved, most scientist believe in it (the STRONG one is less believed because of the quantum computation).
#
# # Benefits about class P:
#
# - Robust (the TM can be defined in many different ways, but that doesn't change the set of languages belonging to P).
#
# - Small exponent empirically (Note that nowadays also algorithm with complexity O(n^8) are useful, for instance in computer vision.
#
# - Nice closure (for instance if L1 is in P and L2 is in P, then also L1 intersection L2, and L1 union L2 are in P.
#
# # Drawbacks about class P:
#
# - worst case not realistic (solutions: approx. algo and average class compl.)
#
# - it is only about decision problems!!
#
# # NP:
# A language L⊆{0,1}∗ is in the class NP iﬀ there exist a polynomial p : N→N and a polynomial time TM M such that :
#
# L = {x ∈{0,1}∗ |∃y ∈{0,1}^p(|x|).M(>x,y<) = 1}
#
# - M is said to be the veriﬁer for L.
#
# - Any y ∈{0,1}^p(|x|) such that M(>x,y<) = 1 is said to be a certiﬁcate FOR X.
#
# - Differently from P and EXP, the class NP does not have a natural counterpart as a class of functions (difficult to be defined).
#
# -  If someone asks you an example of a problem which DOES NOT HAVE a candidate provable in polynomial time YOU DON'T KNOW IT, IF YOU KNEW IT YOU WOULD HAVE PROVED THAT EXP != NP, WHICH IS STILL UNKNOWN.
#
# # NDTM:
# It has 2 transition functions, and at each step it choose non-deterministically one of them.
#
# There's a special state qaccept (not only halt(=reject) ant init; it means that it can happen that the TM halts(=reject), but does not accept!).
#
# - We say the NDTM Accepts the input x ∈{0,1}∗ iﬀ THERE EXIST ONE among the many possible evolutions of the machine M when fed with x which makes it reaching qaccept.
#
# - Rejects the input x ∈{0,1}∗ iﬀ none of the aforementioned evolutions leads to qaccept.
#
# # NDTM runtime:
# We say that a NDTM M runs in time T : N→N iﬀ for every x ∈{0,1}∗ and FOR EVERY POSSIBLE nondeterministic evolution, M reaches either the qhalt or qaccept within c·T(|x|) steps, where c > 0.
#
# # NDTIME(T(n)):
# NDTIME(T(n)) is the set of languages decidable by a NDTM in time T.
#
# # NP alternative definition:
# By using the definition of NDTM we can define the class NP as:
#
# NP = ∪c∈N  NDTIME(n^c)    for c>=1.
#
# # pre-order and  REDUCTION
#
# REDUCTION =  The language L is said to be polynomial-time reducible to another language H iﬀ there is a polytime computable function f : {0,1}∗ →{0,1}∗ such that x ∈L iﬀ f(x) ∈ H.  In this case, we write L≤p H (= THIS IS READ L IS POLYTIME REDUCIBLE TO H).
#
# - Reduction is a PRE-ORDER RELATION: a binary relation which is transitive and reflexive. Why do we need it? to put in DIFFICULTY relation the languages. Indeed L ≤p H means that L is at most as difficult as H, since it is possible to convert it in the H Language and solve it like it. (THIS RELATION IS NOT ANTYSYMMETRIC (INDEED IF A<=B AND B<=A THEN is NOT true that A=B, anyway in that case I can say that they're equivalent in terms of complexity).
#
# - reduction is a function, so if you want to prove the reduction between two languages you need to prove that a function with these properties exists:
#
#
#      - f computable in polynomial time.
#
#     - Domain and codomain are {0,1}*.
#
#     - On input outside of L the output goes outside of H. If the input is a binary string belonging to L, then the output belongs to H. In this way we can prove that INSTANCES OF THE PROBLEM L CAN BE TRANSFORMED/REDUCED IN THE INSTANCES OF THE PROBLEM H, IN A FAITHFUL WAY. INDEED YOU DO A REDUCTION FROM L1 TO L2 ("L1 ≤p L2") IFF THE INSTANCES OF L1, let's call them x1, ARE TRANSFORMED INTO INSTANCES OF L2, let's call them x2, SUCH THAT x1 IS IN L1 IFF x2 IS IN L2.
#
#
# # class FP
#
# What is it? Is exactly the same thing of the class P, but for "function problem". What are the function problem? Are those problems whose output is NOT NECESSARLY only 1/0. Remember this, because there are certain class of functions which can be converted, in a canonical way, from function to a language (so from a problem which takes a string as input and outputs a string, into a problem which simply outpus 0/1), for instance the functions (=problems) of optimization!! note that by optimization function we mean that the optimization problem itself is considered as a function, which taken a mathematical function (converted in string) outputs the variables in which there's the maximum (converted in string), and this holds:
# - any Language which belongs to P can be transformed in a function which belongs to FP (since of course the Boolean functions which are in P are also in FP).
# - also some kind of functions (=optim. problems) can be transformed in a language (because the problem becomes: "is the input above a certain threshold?"). **In general, however, it is not true that the language associated to a function in FP is also in P**.
#
#
# # Class EXP and FEXP:
#
# Are the same as P and FP, but instead of polynomial the bound is $2^{n^c}$
#
# Example: the wedding plan /MIS problem.
#
# Is there a class of algorithms which is something between EXP and P? YES! It is NP. Note that it doesn't exist FNP.<br>
# Note that there are also algorithms which are not solvable in EXP time, for instance the halting problem which is undecidable.
#
# **Note**: We proved that P is different from EXP, so it is strictly included. What about NP? Since we know that P is different from EXP, then NP must strictly include P OR strictly be included in EXP. We still don't know between the two options which is the correct one yet.
#
# **Theorem** <br>
# P ⊆ EXP, FP ⊆ FEXP, these two inclusions are strict.
#
#
#
# # NP-HARD:
# L is NP-hard iff any other language in NP can be reduced to it.  ( note that to be reduced is more strong than simply being more difficult, indeed it means that the language L is a kind of "universal" language which can be used to solve other problems).
#
#
# # NP-complete:
# L is in NP-complete iff it is NP-HARD and it is in NP.
#
#
# # k-CNF:
# The disjunctions in a CNF are said to be clauses, and a kCNF is a CNF whose clauses contains AT MOST k ∈N literals. Examples: the two formulas X ∨¬X and X ∧(Y ∨¬Z) are 2CNFs, but not 1CNFs.
#
# k low -> complexity of kSAT is lower.
#
# # PROVE that L IS NP-COMPLETE:
#
# 1) Prove that L is in NP.
#    - Remember that this requires to show that there are p polynomial and M polytime TM such that L can be written as L = {x ∈{0,1}∗ |∃y ∈{0,1}p(|x|).M(x,y) = 1}. So, show what is the certificate and that it has polynomial length wrt the input, then show that it can be used to check if an input x is the solution in polynomial time with a TM (usually just writing the reasoning).
#
# 2) Prove that any other language H ∈ NP is such that H ≤p L.
#    - We can prove the statement directly (more difficult usually).
#    - More often (e.g. when showing 3SAT NP-complete), one rather proves that J ≤p L for a language J which is already known to be NP-complete. This is correct, simply because ≤p is transitive.
#    - TO PROVE THE REDUCTION YOU MUST PROVE THAT THE REDUCTION CAN BE DONE IN POLYNOMIAL TIME, AND THAT THE NEW INSTANCES ARE LINKED BY "INST1 IN L1 IFF INST2 IN L2".

# %% [markdown]
# # THEOREMS:
#
# # 1) Theorem (UTM, simulation time overhead)
# Theorem:
#
# There exists a TM U such that for every x,α ∈{0,1}∗, it holds that U(x,α) = Mα(x), where Mα denotes the TM represented by α. Moreover, if Mα halts on input x within T steps then U(x,α) halts within CT log(T) steps, where C is independent of |x| and depending only on Mα.
#
# Proof with polynomial overhead instead of logarithmic:
#
# Observations:
#
# 1) The input to U is the pair(x,alpha), where alpha represent a TM M, and x is an input to it.
#
# 2) We assume that M is the TM with:
#    - one working tape
#    - the simple alphabet {0,1,>,blank}.
#
# 3) We have a polynomial overhead because to do the proof we transform the TM into the simplest form above described. AND WE DISCUSSED THAT THE DIFFERENCE BETWEEN THE RUN TIME OF THE MOST COMPLEX TM AND THE SIMPLEST ONE IS POLYNOMIAL!
#    (WHAT ABOUT THE COST OF THE TRANSFORMATION? IT CAN EVEN BE HUGE, WE DON'T CARE BECAUSE IT IS DONE JUST ONCE! IT IS PART OF THE INITIAL SETUP! IS NOT SOMETHING DONE FOR EACH INPUT)
#
# The proof is constructive (= by giving an example of the interested object, or an example of a method to construct such an object).
#
# Let's describe informally U:
#
# - the alphabet is {0,1,>,blank}
#
# - 5 tapes (3 working tapes).
#
# - U uses the input,output,and one working tape in the same way as M. (Not considering that the input tape also contains alpha, because once that's processed as we'll see,the input tape is the same as M).
#
# - the other 2 work tapes are used to store respectively:
#    - an encoding of the transition function of M (extracted from the input tape in the very first steps).
#    - in the other work tape you have an encoding of the current state $q \in Q$ of M. (Why don't we store states usually in other TM? because each TM has already stored it's current state in the register, so the U has its own current state stored, but you need the one of M!!)
#
# <img src="U_tapes.png" height=50% width=50%>
#
# It's clear that after some initial steps needed to build the encoding of the DELTA of Malpha (WHICH ACTUALLY WE DEFINED TO BE EXACTLY THE ENCODING OF Malpha, which is also called alpha), each step of Malpha can be executed on a CONSTANT amount of steps independent on x.
#
# As a consequence the complexity of the simulation stays polynomial RELATIVE TO THE ONE OF Malpha. (BECAUSE IT IS GIVEN BY THE FACT THAT FOR THE PROOF WE SUPPOSED TO CHANGE THE GIVEN TM INTO A SIMPLER FORM WHICH HAS ONLY ONE WORKING TAPE, AND WE KNOW THAT SIMPLER TM HAVE ONLY A POLYNOMIAL OVERHEAD WRT THE MORE COMPLEX ONES!)
#
#
#
# # 2) Theorem (Uncomputable Functions Exist):
# There exists a function uc : {0,1}∗ →{0,1}∗ that is not computable by any Turing Machine.
#
# PROOF:
#
# The proof IS CONSTRUCTIVE, USES DIAGONALIZATION, SO BY CONTRADDICTION:
#
# It suﬃces to consider the function uc(α) = 0 if Mα(α) = 1 ; uc(α) otherwise.
#
# (PAY ATTENTION: THIS IS JUST THE DEFINITION OF uc, WE HAVEN'T A FIXED DEFINITION FOR Muc).
#
# Indeed, if uc were computable, there would be a TM M such that M(α) = uc(α) for every α, and in particular when α = >M<, this would be a contraddiction: uc(>M<)=1 <-> M(>M<) != 1 <-> uc(>M<)=0.
#
# (this proof is by diagonalization, indeed you prove by contraddiction, by relating something to itself.
#
# # 3) Theorem of the uncomputability of the halting problem:
#
# Considering the function halt deﬁned as follows: halt(>(α,x)<) =1 if Mα halts on input x; 0 otherwise
#
# The function halt is not computable by any TM.
#
# Proof:
#
# Suppose by way of contradiction that there's a TM Mhalt which computes the halt function.
#
# We now show that by using Mhalt we can get the Muc able to compute the function uc, which we already proved to be uncomputable, so it is a contradiction (this kind of proof is called reduction).
#
# Let's do it:
#
# The CONSTRUCTION is simple (remember that Muc requires only alpha, not also x):
#
# - On input alpha, Muc CALLs Mhalt on input (aplha,alpha), and:
#      - if Mhalt output is 0 (so if Malpha doesn't halt on alpha, so diverges, so doesn't terminate) then Muc outputs 1.
#
#      - otherwise Muc CALLs U on (alpha,alpha) and CERTAINLY (BECAUSE THIS CASE HAPPENS IF Malpha on alpha converges) obtains a result B. So I am sure that Malpha converges, but it could output 0! In that case Muc should output 1. And vice versa:
#         - if B = 1 then Muc outputs 0.
#         - otherwise outputs 1.
#
# So it can be easily checked that Muc does what it is supposed to do (outputs 0 iff the CALLED machine converges), so it exist, if Mhalt exist!!!
#
# <img src="halt_proof.jfif" width=40%, height=50%>
#
# # 4) $P \subset EXP$ strictly  and HT theorem
#
# - It's easy to prove that P ⊆ EXP, because any TM which works in polytime works also in exponential time.
#
# - We need now to prove that Exp is different from P. We could show an example of a problem which is in Exp and not in P, NOTE THAT IT MEANS TO PROOF THAT IT CAN'T BE PROVED IN POLYNOMIAL TIME! IT IS NOT ENOUGH TO SAY THAT IT ISN'T KNOWN A POLYTIME TM UNTIL NOW. Anyway we want to prove it by proving a stronger thing: the Hierarchy Theorem:
#
# HT states that if f(n) and g(n) are time-constructable functions ad f(n)log(f(n)) = o(g(n)) then DTIME(f(n)) $\subset$ DTIME(g(n)) strictly.
#
# We prove only a case of the HT theorem: ...  DTIME(n) $\subset$ DTIME(n^2) strictly.
#
# To prove it we need to proof that there's one language L which belongs to DTIME(n^2) but not to DTIME(n).
#
# So let's first proof that there's a language L which can be decided in time n^2. We do it by using a particular TM "D" which will allow us to reach a contradiction when we'll show that there's another TM "N" able to decide the language L in time n. SO the proof is done by diagonalization. This is the proof scheme:
#
# <img src="HT_scheme.jpg" >
#
# Now let's show how can we use the HT theorem to prove that P $\subset$ EXP strictly:
#
# - It's easy to prove that P ⊆ EXP, because any TM which works in polytime works also in exponential time.
#
# - we can finally prove that P!=EXP. Consider the two classes DTIME(2^n) and DTIME($2^{2n}$). Consider f(n)=2^n and g(n)=$2^{2n}$. By doing the limit we can easilly see that f(n)log(f(n)) = o (g(n)) ( Do the limit and note that f(n)log(f(n)=2^n log(2^n)= n*2^n and g(n)= 2^{2n}= 2^n * 2^n).
#   Thus thanks to the HT theorem we can say that DTIME(2^n) $\subset$ DTIME($2^{2n}$). This is great because we can say this:
#
# <img src="P_EXP.png">
#
# # 5) P ⊆ NP ⊆ EXP
#
# proof:
#
#   1) P ⊆ NP. To prove it we must show that if L $\in$ P, then L can be written as follows:
#
#      L={x $\in$ {0,1}* | |∃ y  $\in$ {0,1}^p(|x|). M(>x,y<)=1} where p is a polynomial and M is poly-time computable.
#
#      We can do it because we can simply choose p(n)=0 and M as a polytime deterministic machine deciding L (M exists because of the hypothesis that L is in P because we can use the function which solves the problem as a verifier, which ineed is taking as input the empty string+ the input x). This way indeed we obtain  L={x $\in$ {0,1}* | |∃ y  $\in$ {0,1}^0. M(>x,y<)=1} where y is the empty string, so it is equal (with a small encoding difference) to L={x $\in$ {0,1}* | M(>x<)=1}.
#
#   2) NP ⊆ EXP. To prove it we must show that any NP problem can be solved in EXP time. To do that we simply say that any language L $\in$ NP can be DECIDED by trying all possible certificates until you find one for which the pair (input,certificate) satisfy the test of the verifier:
#
#        input = x $\in$ {0,1}*
#
#        for each y in {0,1}^p(|x|) do:
#
#          - simulate M(x,y). M(x,y) output =b.
#
#            if b=1 -> return 1
#
#        return 0
#
#     We need to show that this has exponential time wrt the input. Well, the loop is done for a number of times which is equal to the cartinality of {0,1}^p(|x|) which is 2^p(|x|). Each iteration works in polynomial time because the TM M is poly-time wrt its input, which is itself polynomially bounded. We can call q(|x|) the polynomial time bound of each iteration. So the algorithm is bounded by 2^p(|x|) * q(|x|) = O( 2^p(|x|) * 2^{log(q(|x|))} ) = O( 2^ {p(|x|) + q(|x|)} = O(2^{p(|x|)+q(|x|)}) which is bounded by 2^{n^c} with c big enough, so it is exponential.
#
# # 6) NP = U NDTIME(n^c)  (over all c in N).
#
# Proof:
#
#
# In order to prove the equality it's easier if first we prove "⊇" then "⊆" (or vice versa).
#
#
#
#  - ⊆):
#  <img src="NPtoND.jpg" width=50% height=50% >
#
#  formally:
#   Here we want to prove that if L is in NP, then it is in U NDTIME(n^c).
#    We want to proof that any language in NP, L={x $\in$ {0,1}* | |∃ y  $\in$ {0,1}^p(|x|). M(>x,y<)=1}, can be decided by a NDTM which works in polytime.  Use an NDTM "N" to decide L. N builds all the certificates, one in each branch, by exploiting the nondeterminism. Each branch takes polynomial time since at each step a bit is added, and the length of the certificate is p(|x|) by hypothesis. Only after that, N calls the verifier M in each branch and execute it on the pair input (x,y) WITHOUT NON-DETERMINISM. Of course if M outputs 1 then N halts in qaccept, otherwise it regrets the input x. The overall runtime of N is p(|x|) + q(|x|), where q is the polynomial bounding the M runtime. Since p+q is still a polynomial, then N works in polytime.
#
#  - ⊇):
# <img src="NDtoNP.jpg" width=50% height=50% >
#
# formally:
#   Here we want to prove that if L is in U NDTIME(n^c), then L is in NP.
#   By hypothesis we know that there exist a TM N which works in poly-time p(|x|). The idea is to use such N as a verifier. But the verifier must be a deterministic machine, so how do we do? Simple: the certificate is te SEQUENCE OF ALL THE COICHES OF THE TRANSITION FUNCTION WHICH MUST BE USED AT EACH STEP. Can we use such certificate? Yes becaue since by hypothesis N works in polytime, then such certificate has length p(|x|).
#
#
#
#
#
# # 7)  Theorems about P=NP
#
#    1) The relation ≤p is a pre-order (i.e. it is reﬂexive and transitive).
#
#    2) If L is NP-hard and L∈ P, then P = NP.
#
#    3) If L is NP-complete, then L∈ P iﬀ P = NP.
#
# Proof:
#
# 1)  the professor left this as exercise. I don't knwo if this is right:
#
#   - "≤p" is reflexive: the relation ≤p is reflexive if for any L it holds that L ≤p L.
#      Since L1 ≤p L2 means that L1 is at most as difficult as L2, then if L1=L2=L necessarly that is satisfied.
#
#   - "≤p" is transitive: it means that if A ≤p B and B ≤p C then A ≤p C.
#      By definition the relation A ≤p B means that A is at most as difficult as B, and since B ≤p C means that C is at least as difficult than B, then for sure C is at least as difficult as A, which can be written as A ≤p C.
#
# 2) Proof:
# <img src="NPhard.jpg" width=50% height=50% >
#
#   - ⊆) : it's obvious that P ⊆ NP since any language L in P can be decided in polynomial time, and for sure L can be verified in polynomial time: using the input as certificate and as verifier the TM computing the characteristic function in polynomial time (which is possible thanks to the assumption of L in P).
#
#   -  ⊇): to prove that P ⊇ NP if L is NP-hard and L is in P, we consider a generic language N in NP. N can be reduced to L by definition of NP-hard (which says that L is at least as difficult as all the other NP languages). So N can be decided through L which can be decided in polytime. So any problem in NP can be solved in polytime, which means that NP ⊇ P.
#
#
# 3) Proof:
#
# <img src="NP-complete.jpg" width=50% height=50% >
#
#   - =>) here we prove that if L is NP-complete and in P, then P=NP.
#     We prove it directly by proving the equivalence. By definition of NP-complete L any language N in NP can be reduced to L. By hypothesis L is in P, so any language in N in NP is also in P. And since we know that also any language in P is also in NP, we can say that P=NP. (this is like the all point 2 resumed in one point).
#
#   - <=) here we prove that if P=NP then any L in NP-complete is also in P.
#     If L is NP-complete by definition L is in NP, and by hypothesis it is also in P.
#
#
#
# # 8) TMSAT is NP-complete:
#
# TMSAT = {(α,x,1^n,1^t) |∃u ∈{0,1}^n.Mα outputs 1 on input (x,u) within t steps}
#
# Note: it takes the name because it is like a satisfiability problem for TM rather than for propositional logic. It's like a universal verifier, which works in time bounded by t.
#
# Proof: "It's just the encoding of the concept of NP-completeness into a language."
#
# "Hint by the book to do the proof: A simulation in O(|α|tlogt) time can be obtained by a straightforward adaptation of the proof of Theorem1.13. To do a more eﬃcient simulation, the main idea is to ﬁrst run a simulation of M without actually reading the contents of the work tapes,but rather simply non-deterministically guessing these contents,and writing those guesses down. Then, go over tape by tape and verify that all guesses were consistent."
#
#
#
# # 9) Cuk levain theorem:
#
# Let SAT be the language of all satisﬁable CNF formulae and 3SAT be the language of all satisﬁable 3CNF formulae. Then,
#
# 1. SAT is NP-complete.
#
# 2. 3SAT is NP-complete.
#
# Not a formal proof. Just an idea.
#
# The proof is structured in this way:
#
# First prove that SAT is NP-complete:
#
#   1) show that SAT is in NP.
#
#   2) completeness: any language L in NP can be reduced to SAT (L ≤p SAT).
#      - define a poly-time transformation from string x to CNF formula phi, such that  phi is in SAT IFF x is in L.
#
# Then show that 3SAT is NP-complete by simply showing this: SAT ≤p 3SAT & 3SAT is in NP.

# %% [markdown]
# # FROM PROFESSOR'S EXERCISES:
#
# # MIS formalization:
#
# Given a graph G=(V,E), determine a subset W of V such that:
#
# 1) for all v$\in$W : N(v) $\cap$ W = $\emptyset$, where N(v)={w | {v,w} $\in$ E} % which means that no vertex into the result subset W can be be neighbours.
#
# 2) W has maximum cardinality among all the sets having the property 1.
#
# # DMIS/INDSET  formalization:
# DMIS = INDSET ={x in {0,1}* | x= > (V,E),k <  & MIS(V,E)  >= k }
#
# #  SAT is in NP:
# The certificate is the assignment, the verifier is the TM which exploits the semantic of Prop Logic to show that the formula is true.
#
# #  SAT ≤p 3SAT
#
# See the pdf. The resume is that taken a F= C1^C2^..^Cn where Ci has an arbitrary number of literals, you convert it into 3C1^3C2^..^3Cm where 3Ci has at most 3 literals. To do it you need to "explode" each Ci in a group of 3Ci each composed by less literals. But how do you relate these 3Ci literals in order to obtain a formula 3F which is satisfiable iff F is satisfiable? By introducing cleverly some new variables into the 3Ci clauses which inter-relate the 3Ci clauses. (number of new variables= number of C literals -3)
#
#
# #  The "INDSET" is NP-complete.
#
# Remember that INDSET is the decision problem correspondent to MIS.
# To do it we do a polytime reduction from 3SAT to INDSET.
# When doing this forget about encoding in binary strings, it doesn't matter.
# Each possible clause assignation, BUT THE ONE which makes the clause NOT SATISFIABLE (ONLY ONE SINCE THE VARIABLES ARE LINKED BY "OR" WITHIN A CLAUSE, so the assignment in which all literals are false), are transformed into a node and connected between them by edges (to say that they are mutually exclusive, indeed we use edges to inconsistencies). So in case of 3SAT we have 2^n -1 = 7 nodes per clause. There are other inconsistencies of which we should take care of? Yes: the same variable occurring negated in the assignment into another clause -> there's an inconsistency with these two assignments -> put an edge between them.
# Great, so if we the 3SAT problem is composed by n clauses we need simply to convert it in the former descripted graph and solve INDSET with minimum size of the independent graph = n. Once the subset of consistent assignment has been found it's easy to convert it in the assignment of all the variables of the initial formula F of the 3SAT problem.
#
#
# # 0/1 decisional linear programming is NP-complete.
# First prove that 0/1 decisional linear programming is in NP.
# There's an easy polytime reduction from 3SAT to ILP. check it yourself, possible exercise.
#
# The idea is simple: Let Ci be a clause in 3-SAT, if Ci = (x1, x2, x3) in disjunction form, we construct an inequality equation as x1 + x2 + x3 ≥ 1. If variable xi is in the negate form in clause Ci, we represent it as 1-xi in the inequality equation....
